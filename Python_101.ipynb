# %% [markdown]
# <a href="https://colab.research.google.com/github/vishalsinghtmas-maker/Rebounce-Applied-AI-and-Analytics-Codes/blob/main/Python_101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("MP1 starting")
# Out:
# MP1 starting

# %% [markdown]
# ## Problem 1 . The introductory card

# %%
name = "vishal"
city ="gurgaon"
birth_year = 1999
age = 2026 - birth_year
print("hi, i am ", name,"." , "i live in ",city, "and my age is",age, "years old")
# Out:
# hi, i am  vishal . i live in  gurgaon and my age is 27 years old

# %% [markdown]
# ## Problem 2. The currency exchange

# %%
inr = 75000
yen = 1.75
print ('75000  convert to', yen* inr)
# Out:
# 75000  convert to 131250.0

# %% [markdown]
# ## Problem 3 . The grocery bill

# %%
bread = 40
milk =  65
eggs = 120
print("total:", bread+milk+eggs)
print("average per item:", (bread+eggs+milk)/3)
# Out:
# total: 225
# average per item: 75.0

# %% [markdown]
# ## Problem 4 . odd or even?

# %%
number = 98
remainder = number % 2
is_even = remainder ==0
print ( "Is",number, "even?",is_even)
# Out:
# Is 98 even? True

# %% [markdown]
# ## Problem 5. The password strength check

# %%
password = "abcdef@1"
length_ok = len(password)>=8
contains = "@" in password
strong = length_ok and contains
print("password:", password, )
print("length_ok:", length_ok)
print("contains @ :", contains)
print("strong:", strong)
# Out:
# password: abcdef@1
# length_ok: True
# contains @ : True
# strong: True

# %% [markdown]
# ##Problem 6. The class roster

# %%
Attendees = ["jay" , "vishal", "varun", "aarav", "priya", "rohan","ishan","diya"]
print(len(Attendees))
print("first:", Attendees[0])
print("last two:",Attendees[6:])
Attendees.sort()
print("first three alphabetically:", Attendees[:3])
# Out:
# 8
# first: jay
# last two: ['ishan', 'diya']
# first three alphabetically: ['aarav', 'diya', 'ishan']

# %% [markdown]
# ## Problem 7. The contact book

# %%
phone_directory ={"vishal": 7777777722, "ravan":1234567891, "anand":9876543218, "ram": 9876543992,"diksha": 5556664444}
phone_directory["abhishek"]= 9899898989
print("anand's number:",phone_directory["anand"])
print("after adding abhishek:", len(phone_directory))
# Out:
# anand's number: 9876543218
# after adding abhishek: 6

# %% [markdown]
# ## Problem 8. The square of even numbers

# %%
squares = [ num**2 for num in range(1,21) if num % 2 ==0 ]
print(squares)
# Out:
# [4, 16, 36, 64, 100, 144, 196, 256, 324, 400]

# %% [markdown]
# ## Problem 9. Sort products by price

# %%
products = [
    ("notebook", 250),
    ("pen",  20),
    ("backpack", 1800),
    ( "Eraser",15),
    ("water bottle", 350)
]

products.sort( key= lambda products: products[1])
print(products)
# Out:
# [('Eraser', 15), ('pen', 20), ('notebook', 250), ('water bottle', 350), ('backpack', 1800)]

# %% [markdown]
# ## Problem 10. Filter the passing students

# %%
scores ={
    "anika": 35,
    "rohan": 72,
    "meera": 40,
    "kabir": 28,
    "diya": 88,
    "ishan": 55,
}
passing_students =list(filter(lambda key:scores[key]>= 40, scores))
print( "passing students:", passing_students)
# Out:
# passing students: ['rohan', 'meera', 'diya', 'ishan']
